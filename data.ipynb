# %%
#graph program
import matplotlib.pyplot as plt

# Create data
x = range(1, 6)
y = [1, 4, 8, 3, 6]

# Area plot
plt.fill_between(x, y, color='lightblue')

# Show the graph
plt.show()

# %%
# histogram
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)  # Generate random data

# Create histogram
plt.hist(data, bins=20, color='lightgreen', edgecolor='black')  # Fixed the quote here
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plots
plt.show()

# %%
#Importing libraries
import pandas as pd
import numpy as np

#Creating a DataFrame
data={
'Name': ['Saransh', 'Shiwali', 'Shivansh', 'Sukruti', 'Shaan'],
'Age': [19,20,25,22,23],
'City': ['New Delhi', 'Banglore', 'Hyderabad', 'Mumbai', 'Pune']
}

df=pd.DataFrame(data)
df
# Out:
#        Name  Age       City
# 0   Saransh   19  New Delhi
# 1   Shiwali   20   Banglore
# 2  Shivansh   25  Hyderabad
# 3   Sukruti   22     Mumbai
# 4     Shaan   23       Pune

# %%
df.head()
# Out:
#        Name  Age       City
# 0   Saransh   19  New Delhi
# 1   Shiwali   20   Banglore
# 2  Shivansh   25  Hyderabad
# 3   Sukruti   22     Mumbai
# 4     Shaan   23       Pune

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   21.800000
# std     2.387467
# min    19.000000
# 25%    20.000000
# 50%    22.000000
# 75%    23.000000
# max    25.000000

# %%
df['Age_in_Months']=df['Age']*12
df
# Out:
#        Name  Age       City  Age_in_Months
# 0   Saransh   19  New Delhi            228
# 1   Shiwali   20   Banglore            240
# 2  Shivansh   25  Hyderabad            300
# 3   Sukruti   22     Mumbai            264
# 4     Shaan   23       Pune            276

# %%
filtered_df=df[df['Age']<30]
filtered_df
# Out:
#        Name  Age       City  Age_in_Months
# 0   Saransh   19  New Delhi            228
# 1   Shiwali   20   Banglore            240
# 2  Shivansh   25  Hyderabad            300
# 3   Sukruti   22     Mumbai            264
# 4     Shaan   23       Pune            276

# %%
sorted_df=df.sort_values(by='Age')
sorted_df
# Out:
#        Name  Age       City  Age_in_Months
# 0   Saransh   19  New Delhi            228
# 1   Shiwali   20   Banglore            240
# 3   Sukruti   22     Mumbai            264
# 4     Shaan   23       Pune            276
# 2  Shivansh   25  Hyderabad            300

# %%
df.loc[2,'city']=np.nan
df
# Out:
#        Name  Age       City  Age_in_Months  city
# 0   Saransh   19  New Delhi            228   NaN
# 1   Shiwali   20   Banglore            240   NaN
# 2  Shivansh   25  Hyderabad            300   NaN
# 3   Sukruti   22     Mumbai            264   NaN
# 4     Shaan   23       Pune            276   NaN

# %%
#Save DataFrame to CSV
df.to_csv('manipulated_data.csv',index=True)
#Creating a Series from a list
data_list=[10,20,30,40,50]
series_list=pd.Series(data_list, name='Values')
series_list
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Values, dtype: int64

# %%
#Creating a Series from a dictionary
data_dict={'A':100,'B':200,'C':300,'D':400}
series_dict=pd.Series(data_dict,name='Scores')
series_dict
# Out:
# A    100
# B    200
# C    300
# D    400
# Name: Scores, dtype: int64

# %%
#Accesing data by integer index
value_at_index_2=series_list[2]
value_at_index_2
# Out:
# 30

# %%
#Accessing data by label
score_A=series_dict['A']
score_A
# Out:
# 100

# %%
import matplotlib.pyplot as plt
#Adjusted data with the same size
hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]
test_scores = [50, 55, 60, 65, 70, 75, 80, 85]
#Trimmed to 8 elements
#Create scatter plot
plt.figure(figsize=(8,6))
plt.scatter(hours_studied, test_scores, color='blue', marker='D')
#Add title and labels
plt.title('Scatter Plot of Hours Studied vs. Test Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Test Score')
plt.grid(True)

# %%
import matplotlib.pyplot as pit
#Sample data
hours_studied = [1, 2, 3, 4, 5, 6, 7, 8]
test_scores = [50, 55, 60, 65, 70, 75, 80, 85]
bubble_size = [200, 400, 600, 800, 500, 300, 900, 1000] #Bubble sizes for each point
#Create bubble chart
plt.figure(figsize=(8,6))
plt.scatter(hours_studied, test_scores, s=bubble_size, color='blue', alpha=0.5)
#Add title and labels
plt.title('Bubble Chart of Hours Studied vs. Test Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Test Score')
plt.grid(True)
#Display the plot
plt.show()

# %%
#Importing libraries
import pandas as pd 
import numpy as np
# Creating the DataFrame 
data={
'Name':['Alice', 'Bob','Charlie', 'David', 'Alice', 'Eve'],
'Age':[25.0,30.0,35.0,40.0,25.0,np.nan],
'City': ['New York', 'Los Angeles','New York','Chicago','New York', 'Los Angeles']
}
df=pd.DataFrame(data)
#1. Using count() count the not-null/NA entries
not_null_count=df.count() 
print("Count of not-null/NA entries:\n",not_null_count)
# Out:
# Count of not-null/NA entries:
#  Name    6
# Age     5
# City    6
# dtype: int64

# %%
#2. Using describe() give the statistical description of the dataframe
statistical_description=df.describe() 
print("\nStatistical description of the dataframe:\n",statistical_description)
# Out:
# Statistical description of the dataframe:
#               Age
# count   5.000000
# mean   31.000000
# std     6.519202
# min    25.000000
# 25%    25.000000
# 50%    30.000000
# 75%    35.000000
# max    40.000000

# %%
#3. Drop duplicates using drop_duplicates()
df_no_duplicates=df.drop_duplicates() 
print("\nDataFrame after dropping duplicates:\n",df_no_duplicates)
# Out:
# DataFrame after dropping duplicates:
#        Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob  30.0  Los Angeles
# 2  Charlie  35.0     New York
# 3    David  40.0      Chicago
# 5      Eve   NaN  Los Angeles

# %%
#4. Check whether dataframe is empty using empty() property

is_empty=df.empty 
print("\nIs the original DataFrame empty?\n",is_empty)
# Out:
# Is the original DataFrame empty?
#  False

# %%
#5. Filter the records containing city as New York

new_york_df=df[df['City']=='New York'] 
print("\nRecords containing City as 'New York':\n",new_york_df)
# Out:
# Records containing City as 'New York':
#        Name   Age      City
# 0    Alice  25.0  New York
# 2  Charlie  35.0  New York
# 4    Alice  25.0  New York

# %%
#6. Create a copy of dataframe and compare the original and the copy

df_copy=pd.DataFrame(data) 
are_equal=df.equals(df_copy) 
print("\nAre the original DataFrame equals to its copy ?\n",are_equal)
# Out:
# Are the original DataFrame equals to its copy ?
#  True

# %%
#Importing Libraries
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
#Text Data
text = "Python is a great programming language. Python is widely used for data analysis, machine learning, and web development."
#Create a WordCloud Object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
#Display the WordCloud using Matplotlib
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Importing Libraries
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
# Creating DataFrame
np.random.seed(0) 
x=np.random.rand(100)
y=2*x+np.random.normal(0,0.1,100)
data=pd.DataFrame({'x':x,'y':y})
sns.boxplot(data)
# Out:
# <Axes: >

# %%
import seaborn as sns
# Load the dataset
dataset = sns.load_dataset('tips')
# Display the first few rows of the dataset
print(dataset.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')
sns.lmplot(x='total_bill', y='tip', data=dataset, hue='sex', markers=['o','v'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Load the dataset
dataset = sns.load_dataset('tips')
# Create a scatter plot
sns.scatterplot(x='total_bill', y='tip', data=dataset, hue='sex', 
                style='sex', markers=['o', 'v'], 
                s=200, palette='plasma')
# Show the plot
plt.show()

# %%
sns.kdeplot(dataset['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Importing Libraries
import folium
my_map = folium.Map(location = [16.9902, 73.3120], zoom_start = 12)
folium.Marker([16.9902, 73.3120], popup = 'Ratnagiri').add_to(my_map)
folium.Marker([20.9042, 74.7749], popup = 'Dhule').add_to(my_map)
folium.PolyLine(locations = [(16.9902, 73.3120), (20.9042, 74.7749)], line_opacity= 0.5).add_to(my_map)
#my_map.save("my_map.html")
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Importing the libraries
import folium
#Step 1: Creating a map centered on Dhule, Maharashtra, India 
maharashtra_map = folium.Map(location=[20.9042, 74.7749], zoom_start=10, tiles = 'Stamen Terrain') 
#Step 2: Adding markers to the map for nearby cities
#Adding a marker at Dhule 
folium.Marker([20.9042, 74.7749],popup="Dhule").add_to(maharashtra_map)
#Adding a marker at Malegaon 
folium.Marker([20.5500, 74.5333],popup="Malegaon").add_to(maharashtra_map)
#Adding a marker at Jalgaon 
folium.Marker([21.0067, 75.5626],popup="Jalgaon").add_to(maharashtra_map)
# Adding a marker at Nasik 
folium.Marker([19.9975, 73.7898],popup="Nasik").add_to(maharashtra_map)
#Adding a marker at Aurangabad
folium.Marker([19.8762, 75.3433], popup="Aurangabad").add_to(maharashtra_map)
#Step 3: Choropleth Map for Maharashtra (simplified, using hypothetical population data for districts)
#Sample data for district populations (hypothetical example, usually you would use actual data)
district_population = {
'Dhule': 2050863, 'Malegaon': 4710065, 'Jalgaon': 4224442, 'Nasik': 6109052, 'Aurangabad': 3701282
}
#Step 4: Display the map with markers
maharashtra_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
